# %% [markdown]
# # EC2 Spot diversification and price history
#
# * **Author:** Carlos Manzanedo Rueda <ruecarlo@amazon.com>
# * **License:** This notebook is released under [Apache v2.0 License](https://www.apache.org/licenses/LICENSE-2.0.txt)
#
#
# This jupyter notebook uses pandas and matplotlib to plot EC2 Spot historic price changes for comparison across different regions, family and instance sizes.
#
# The code is intended as an example of how to explore EC2 Spot historic prices. Perhaps it's obvious, but please note that historic EC2 price does not define future spot market behaviours!
#
# When constructing a strong and EC2 Fleet, Spot Fleet or Auto Scaling Groups two of the main best practices are: (a) flexibility and (b) diversification. This jupyter notebook allows to visualise changes in the EC2 Spot historic price across regions and instance types. History goes back 3 months (EC2 Spot history API limit). This notebook intends to convey an intuition of why implementing diversification is so important with EC2 Spot as well as helping to compare different instance types and families across regions.
#
# Michael: I ran t his in a python 3.9.16 env, not all the python packages are needed but I had issues getting the matplotlib to work

# %%
# !pip3 install --upgrade pandas tqdm boto3 pandas matplotlib ipywidgets widgetsnbextension pandas-profiling jupyter_contrib_nbextensions jupyterlab_widgets xlsxwriter
# Out:
# Requirement already satisfied: pandas in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (1.5.3)
# Collecting pandas
#   Using cached pandas-2.0.0-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
# Requirement already satisfied: tqdm in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (4.64.1)
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: boto3 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (1.26.108)
# Requirement already satisfied: matplotlib in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (3.6.3)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp39-cp39-macosx_11_0_arm64.whl (7.3 MB)
# Requirement already satisfied: ipywidgets in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (8.0.6)
# Requirement already satisfied: widgetsnbextension in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (4.0.7)
# Requirement already satisfied: pandas-profiling in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (3.6.6)
# Requirement already satisfied: jupyter_contrib_nbextensions in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (0.7.0)
# Requirement already satisfied: jupyterlab_widgets in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (3.0.7)
# Requirement already satisfied: xlsxwriter in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.20.3 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from boto3) (0.6.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.108 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from boto3) (1.29.108)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipywidgets) (6.22.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: ydata-profiling in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from pandas-profiling) (4.1.2)
# Requirement already satisfied: notebook>=6.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (6.5.4)
# Requirement already satisfied: tornado in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: ipython-genutils in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (0.6.1)
# Requirement already satisfied: nbconvert>=6.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (7.3.0)
# Requirement already satisfied: jupyter-core in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Requirement already satisfied: lxml in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (4.9.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from botocore<1.30.0,>=1.29.108->boto3) (1.26.12)
# Requirement already satisfied: zipp>=3.1.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.10.0)
# Requirement already satisfied: pyzmq>=20 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: nest-asyncio in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: appnope in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: psutil in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.8.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: comm>=0.1.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.1.0)
# Requirement already satisfied: backcall in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: stack-data in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pickleshare in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: decorator in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: typing-extensions in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.4.0)
# Requirement already satisfied: setuptools in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (65.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-core->jupyter_contrib_nbextensions) (2.5.4)
# Requirement already satisfied: pyyaml in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.3)
# Requirement already satisfied: markupsafe>=2.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.0.0)
# Requirement already satisfied: beautifulsoup4 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.2)
# Requirement already satisfied: bleach in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.0.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: nbformat>=5.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.8.0)
# Requirement already satisfied: jinja2>=3.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: defusedxml in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: tinycss2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: prometheus-client in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: argon2-cffi in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.5.5)
# Requirement already satisfied: six>=1.5 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.12.3)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.13.5)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.10.2)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.8.1)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.7.5)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: PyWavelets in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.4.1)
# Requirement already satisfied: attrs>=19.3.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.8)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: fastjsonschema in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: joblib>=0.14.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: wcwidth in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2022.9.24)
# Requirement already satisfied: patsy>=0.5.2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.3)
# Requirement already satisfied: argon2-cffi-bindings in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.4)
# Requirement already satisfied: webencodings in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: websocket-client in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: pycparser in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: fqdn in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.3)
# Requirement already satisfied: isoduration in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.13)
# Requirement already satisfied: uri-template in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.0)
# Requirement already satisfied: arrow>=0.15.0 in /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %matplotlib inline
import boto3
import requests
import datetime
from dateutil.tz import *
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from tqdm import tqdm
from tqdm.notebook import tqdm as tqdm_notebook
from tqdm.notebook import tnrange
from IPython.core.display import display, HTML
import ipywidgets as widgets
display(HTML("<style>.container { width:100% !important; }</style>"))
tqdm.pandas()
## Current version of pandas and matplotlib throw a few warnings
## Next version of pandas should remove those
import warnings
warnings.filterwarnings('ignore')

# uncomment the profile_name should you use STS and profiles
# You can read more about profiles and STS here 
# https://docs.aws.amazon.com/cli/latest/userguide/cli-configure-role.html
# profile_name = "miclip"
# Out:
# /var/folders/61/j2t3hcy16y361_k5lmv6jsvm0000gr/T/ipykernel_89638/3052760969.py:12: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
# %%javascript
# //Some outputs may create large results. This disables the scrolling within jupyter for those.
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ##  Fetching Regions and Instance types
#
# The following section queries the regions and then queries which instance types are available in each region. This may take a few seconds up to a minute.

# %%
# !jupyter contrib nbextension install --user
# !jupyter nbextension enable varInspector/main
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# [I 12:41:29 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 12:41:29 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/rubberband/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/rubberband/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/rubberband/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/rubberband/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/rubberband/rubberband.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scroll_down/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scroll_down/config.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scroll_down/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scroll_down/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/hinterland -> hinterland
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hinterland/hinterland.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hinterland/hinterland.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hinterland/README.md
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets -> snippets
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets/snippets.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets/snippets.json
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets/snippets-demo.gif
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/toggle_all_line_numbers -> toggle_all_line_numbers
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toggle_all_line_numbers/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toggle_all_line_numbers/main.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toggle_all_line_numbers/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toggle_all_line_numbers/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/notify -> notify
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/notify/notify.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/notify/notify.mp3
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/notify/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/notify/notify.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/notify/notification.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/runtools -> runtools
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/cellstate.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/runtools_execute.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/annotations.odg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/runtools.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/runtools_nb.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/runtools_marker.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/runtools_show_hide.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/runtools_lock.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/demo.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/runtools/gutter.css
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/tree-filter -> tree-filter
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/tree-filter/tree-filter.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/tree-filter/index.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/tree-filter/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/tree-filter/demo.gif
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/table_beautifier -> table_beautifier
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/table_beautifier/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/table_beautifier/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/table_beautifier/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/table_beautifier/table_beautifier.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/freeze/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/freeze/config.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/freeze/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/freeze/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2 -> exercise2
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise2/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise2/exercise2.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise2/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise2/image.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise2/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise2/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies -> execution_dependencies
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execution_dependencies/execution_dependencies.yml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execution_dependencies/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execution_dependencies/execution_dependencies.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/skill -> skill
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skill/skill.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skill/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skill/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skill/skill.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell -> splitcell
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/splitcell/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/splitcell/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/splitcell/splitcell.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/splitcell/splitcell.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime -> autosavetime
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autosavetime/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autosavetime/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autosavetime/autosavetime.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autosavetime/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/select_keymap/select_keymap.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/select_keymap/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/select_keymap/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/livemdpreview -> livemdpreview
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/livemdpreview/livemdpreview.yml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/livemdpreview/livemdpreview.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/gist_it -> gist_it
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/gist_it/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/gist_it/gist_it.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/gist_it/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/gist_it/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/cell_filter -> cell_filter
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/cell_filter/cell_filter.yml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/cell_filter/cell_filter.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/cell_filter/README.md
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scratchpad/LICENSE
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scratchpad/scratchpad.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scratchpad/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scratchpad/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scratchpad/scratchpad.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/scratchpad/demo.gif
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/toc2 -> toc2
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/toc2.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/demo_dark.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/demo3.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/demo2.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/toc2.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/demo.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/toc2/image.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate -> nbTranslate
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/nbTranslate.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/nbTranslate.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/demo1.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/demo2.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/languages.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/nbTranslate/mutils.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering -> equation-numbering
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/equation-numbering/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/equation-numbering/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/equation-numbering/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/equation-numbering/info.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/equation-numbering/button.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/navigation-hotkeys -> navigation-hotkeys
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/navigation-hotkeys/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/navigation-hotkeys/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/navigation-hotkeys/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/navigation-hotkeys/hotkeys.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu -> snippets_menu
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_menu.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenu_python.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/config.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenu_markdown.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/thumbnail.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/screenshot1.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/screenshot2.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/screenshot3.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/examples_for_custom.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_ufuncs.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numba.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_assumptions.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/astropy.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/pandas.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_polynomial.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_constants.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/matplotlib.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_functions.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/h5py.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_special.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/python_regex.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/python.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/printview -> printview
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/printview/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/printview/printview-button.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/printview/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/printview/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/printview/printview.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded -> export_embedded
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/export_embedded/export_embedded.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/export_embedded/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/export_embedded/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/export_embedded/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll -> autoscroll
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autoscroll/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autoscroll/autoscroll.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autoscroll/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/autoscroll/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input -> hide_input
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input/hide-input.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all -> hide_input_all
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input_all/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input_all/hide_input_all.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input_all/hide_input_all_show.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input_all/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input_all/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_input_all/hide_input_all_hide.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor -> keyboard_shortcut_editor
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_comma.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_dropdown.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/kse_components.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_conflict.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_menu_item.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel -> help_panel
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/help_panel_ext.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/help_panel_ext_fullscreen.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/help_panel.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/help_panel.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/help_panel.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/help_panel/img/handle-v.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/move_selected_cells -> move_selected_cells
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/move_selected_cells/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/move_selected_cells/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/move_selected_cells/move_selected_cells.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/zenmode -> zenmode
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/zenmode.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back12.jpg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back11.jpg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back2.jpg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back3.jpg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back1.jpg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/ipynblogo1.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/ipynblogo0.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back21.jpg
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/zenmode/images/back22.jpg
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/skip-traceback -> skip-traceback
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skip-traceback/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skip-traceback/traceback.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skip-traceback/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skip-traceback/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skip-traceback/skip-traceback.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/skip-traceback/skip-traceback.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/python-markdown -> python-markdown
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/untrusted.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/python-markdown-pre.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/python-markdown.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/trusted.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/python-markdown.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/python-markdown/python-markdown-post.png
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/edit.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/magic-fold.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/firstline-fold.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/foldgutter.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/magic-folded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/blockcomment-fold.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/edit.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/magic-fold.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/firstline-fold.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/foldgutter.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/magic-folded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codefolding/blockcomment-fold.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings -> collapsible_headings
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/collapsible_headings/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/collapsible_headings/screenshot.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/collapsible_headings/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/collapsible_headings/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/collapsible_headings/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/collapsible_headings/collapsible_headings.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise -> exercise
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/history.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/image.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/exercise/exercise.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/codemirror_mode_extensions -> codemirror_mode_extensions
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codemirror_mode_extensions/codemirror_mode_extensions.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/codemirror_mode_extensions/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/edit.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/ruler.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/edit.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/ruler/ruler.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item -> contrib_nbextensions_help_item
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/contrib_nbextensions_help_item/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/contrib_nbextensions_help_item/main.js
# ...
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/execute_time -> execute_time
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/ExecuteTime.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/execution-timings-box.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/ExecuteTime.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/ExecuteTime.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/execution-timings-menu.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/execute_time/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/spellchecker -> spellchecker
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/download_new_dict.py
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/screenshot.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/config.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/main.css
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/main.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/typo/typo.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/typo/LICENSE.txt
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/spellchecker/__pycache__/download_new_dict.cpython-39.pyc
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-py.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_2to3.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_isort.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-R.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-py.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_2to3.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_isort.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-R.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-py.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_2to3.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_isort.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-R.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-py.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_2to3.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_isort.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/demo-R.gif
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros -> load_tex_macros
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/load_tex_macros/load_tex_macros.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/load_tex_macros/icon.png
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/load_tex_macros/readme.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/load_tex_macros/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_header -> hide_header
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_header/hide_header.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_header/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/hide_header/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing /Users/miclip/.pyenv/versions/3.9.15/lib/python3.9/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/highlight_selected_word/README.md
# [I 12:41:29 InstallContribNbextensionsApp] Up to date: /Users/miclip/Library/Jupyter/nbextensions/highlight_selected_word/main.js
# [I 12:41:29 InstallContribNbextensionsApp] - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /Users/miclip/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /Users/miclip/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.6.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 12:41:29 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 12:41:29 InstallContribNbextensionsApp]       - Validating: OK
# [I 12:41:29 InstallContribNbextensionsApp] - Editing config: /Users/miclip/.jupyter/jupyter_nbconvert_config.json
# [I 12:41:29 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 12:41:29 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 12:41:29 InstallContribNbextensionsApp] - Writing config: /Users/miclip/.jupyter/jupyter_nbconvert_config.json
# [I 12:41:29 InstallContribNbextensionsApp] --  Writing updated config file /Users/miclip/.jupyter/jupyter_nbconvert_config.json
# Enabling notebook extension varInspector/main...
#       - Validating: OK
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %% [markdown]
# Michael: AWS uses a cli tool to authenicate to our lab environments which meant I had to provde these tempoary credentals.

# %%
aws_access_key_id=""
aws_secret_access_key=""
aws_session_token=""

# %%
def getEC2RegionNames(region='us-west-2',aws_session_token=aws_session_token,aws_secret_access_key=aws_secret_access_key,aws_access_key_id=aws_access_key_id ):
    session = boto3.session.Session(region_name=region,aws_session_token=aws_session_token,aws_secret_access_key=aws_secret_access_key,aws_access_key_id=aws_access_key_id)
    ec2_client = session.client('ec2')
    # exception handling
    regions_response = ec2_client.describe_regions()
    return [ region['RegionName'] for region in regions_response['Regions']]

def getInstanceTypesInRegion(region='us-west-2',aws_session_token=aws_session_token,aws_secret_access_key=aws_secret_access_key,aws_access_key_id=aws_access_key_id ):
    session = boto3.session.Session(region_name=region,aws_session_token=aws_session_token,aws_secret_access_key=aws_secret_access_key,aws_access_key_id=aws_access_key_id)
    ec2_client = session.client('ec2')
    instance_types_offering = ec2_client.describe_instance_type_offerings(LocationType='region')
    return [it['InstanceType'] for it in instance_types_offering['InstanceTypeOfferings']]
    
def getGlobalInstanceTypes():
    regions = getEC2RegionNames()
    instance_type_set = set([])
    for region in tqdm_notebook(regions):
        instances_types = getInstanceTypesInRegion( region=region)
        for instance_type in instances_types:
            instance_type_set.add(instance_type)
    return instance_type_set

regions_to_compare = sorted(getEC2RegionNames())
instances_to_complare = sorted(list(getGlobalInstanceTypes()))

# Add the regions and instances you are interested to explore
regions_w = widgets.SelectMultiple(
    options=regions_to_compare,
    value=regions_to_compare,
    description='Region:'
)
instances_w = widgets.SelectMultiple(
    options=instances_to_complare,
    value=instances_to_complare,
    description='Instance:',
    style={'height': str(30*len(instances_to_complare))}
)
days_back_w = widgets.IntSlider(
    value=30,min=1,max=90,step=1,
    description='Days back:',
)
cap_price_w = widgets.BoundedFloatText(
    value=1.0,
    min=0,
    max=40.0,
    step=0.01,
    description='Max Price',
    disabled=False
)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]

# %% [markdown]
# With all the regions and instance types, we can now provide some filtering option to select which instances types and regions will be considered as well as how far back to look in the spot price history
#
# [Since Nov 2017 EC2 pricing model does not use bidding anymore](https://aws.amazon.com/blogs/compute/new-amazon-ec2-spot-pricing/). Some API's may still refer to it that way but the entry for bidding must be now interpreted as a max price to state how much you are willing to spend on a diversified fleet of instance types and families. This will draw a horizontal line in the charts that can help understand which instances/types will be below the max price.

# %%
display(widgets.HBox([widgets.VBox([days_back_w,cap_price_w]), instances_w, regions_w]))
# Out:
# HBox(children=(VBox(children=(IntSlider(value=30, description='Days back:', max=180, min=1), BoundedFloatText(…

# %% [markdown]
# ## Fetching Spot Historic Prices and building up the data-frames
#
# Finally we setup our functions and start making API calls to query EC2 Spot price using the `describe_spot_price_history`.
# We also define the functions that will plot the final results.
#
# **TO-DO** The method can be optimised to search for all the instances within a region and then construct the pandas frame. At the moment is done the other way around, each instance price history is built within it's own pandas frame, re-sampled and then concatenated only when required. This increases the number of calls in the API. This shouldn't be an issue unless a comparison against many many instances is required.

# %%
def paginate(method, **kwargs):
    client = method.__self__
    paginator = client.get_paginator(method.__name__)
    for page in paginator.paginate(**kwargs).result_key_iters():
        for item in page:
            yield item

def fetch_spot_price_history_for_instance_in_region(region, instance, days_back=30, op_sys="Linux/UNIX", profile_name="",resolution='60T'):
    session = boto3.session.Session( region_name=region,
                                    aws_session_token=aws_session_token,aws_secret_access_key=aws_secret_access_key,aws_access_key_id=aws_access_key_id)
    ec2_client = session.client('ec2')
    start_time = datetime.datetime.now() - datetime.timedelta(days=days_back)
    response = ec2_client.describe_spot_price_history(
        InstanceTypes=[instance],
        MaxResults=10000,
        ProductDescriptions = [op_sys],
        StartTime=start_time)
    
    indices = None
    values = []
    for resp in paginate(ec2_client.describe_spot_price_history, InstanceTypes=[instance], ProductDescriptions = [op_sys], StartTime=start_time, MaxResults=10000):
        if indices is None:
            indices = list(resp.keys())
        values.append(list(resp.values()))
    spot_prices = pd.DataFrame(values,columns=indices)
    print("Got response for {} {} {}".format(region, instance, start_time))
    spot_prices["Timestamp"] = spot_prices['Timestamp'].astype('datetime64[ns]')
    spot_prices.set_index("Timestamp", inplace=True)
    spot_prices.tz_localize(tz=tzutc())
    spot_prices["SpotPrice"] = spot_prices.SpotPrice.astype(float)
    spot_prices.sort_index(inplace=True)
    az_df_dict = {az:pd.Series(df['SpotPrice'],name=az) for az,df in spot_prices.groupby("AvailabilityZone")}
    spot_prices = pd.concat(list(az_df_dict.values()),axis=1)
    spot_prices.loc[pd.Timestamp.now()] = spot_prices.tail(1).copy().iloc[0]
    spot_prices.fillna(method='ffill',inplace=True)
    spot_prices.fillna(method='bfill',inplace=True)
    spot_prices = spot_prices.resample(resolution).ffill()
    spot_prices.fillna(method='bfill',inplace=True)
    spot_prices.columns = [f'{instance}-{c}' for c in spot_prices]
    return spot_prices    

def fetch_spot_price_history(regions, instances, days_back=30, op_sys="Linux/UNIX", profile_name="",resolution='5T'):
    ret = {}
    for region in tqdm_notebook(regions):
        ret[region] = {}
        for instance in tqdm_notebook(instances):
            try:
                ret[region][instance] = fetch_spot_price_history_for_instance_in_region(region, instance, days_back=days_back, op_sys=op_sys, profile_name=profile_name, resolution=resolution)
            except Exception as error:
                #print("Got error when fetching {} on region {} : {}".format(instance, region, error))
                pass
    return ret

def plot_spot_prices_grid(bid_price, spot_prices_dict,instances_w,regions_w):
    region_x_pos = 0
    fig, ax = plt.subplots(len(instances_w.value),len(regions_w.value),sharex='all', sharey='all',figsize=[24,4],squeeze=False)
    plt.subplots_adjust(bottom=1,top=5)
    for region_name, inst_dic in spot_prices_dict.items():
        instance_y_pos = 0
        for instance_name, spot_price_df in inst_dic.items():
            spot_price_df.plot(ax=ax[instance_y_pos, region_x_pos])
            ax[instance_y_pos, region_x_pos].set_title("{} {}".format(region_name, instance_name))
            ax[instance_y_pos, region_x_pos].axhline(y=bid_price,linewidth=3, color='black')
            ax[instance_y_pos, region_x_pos].minorticks_on()
            ax[instance_y_pos, region_x_pos].grid(which='major', linestyle=':', linewidth='0.1',color='black')
            instance_y_pos += 1
        region_x_pos += 1

def plot_spot_aggregated_by_region(bid_price, spot_prices_dict,instances_w,regions_w, resolution='60T', legend=True):
    region_x_pos = 0
    spot_history = None
    fig, ax = plt.subplots(1,len(regions_w.value), sharex='all', sharey='all',figsize=[30,16],squeeze=False)
    for region_name, inst_dic in spot_prices_dict.items():
        if len(inst_dic.items())==0:
            continue
        spot_history = pd.concat([v for k,v in inst_dic.items()],sort=False)
        spot_history = spot_history.resample(resolution)
        spot_history = spot_history.apply(lambda x: x.fillna(method='ffill'))
        spot_history = spot_history.apply(lambda x: x.fillna(method='bfill'))  
        spot_history.plot(ax=ax[0, region_x_pos])
        ax[0,region_x_pos].set_title("{}".format(region_name))
        ax[0,region_x_pos].axhline(y=bid_price,linewidth=3, color='black')
        ax[0,region_x_pos].minorticks_on()        
        ax[0,region_x_pos].grid(which='major', linestyle=':', linewidth='0.1',color='black')
        if not legend:
            ax[0,region_x_pos].get_legend().remove()
        region_x_pos += 1

# %%
spot_prices_dict = fetch_spot_price_history(
    regions=regions_w.value, 
    instances=instances_w.value,
    days_back=days_back_w.value,
    profile_name=profile_name)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Got response for us-west-1 a1.medium 2022-10-09 17:05:38.451253
# Got response for us-west-1 c7g.16xlarge 2022-10-09 17:05:39.202616
#   0%|          | 0/2 [00:00<?, ?it/s]
# Got response for us-west-2 a1.medium 2022-10-09 17:05:39.550615
# Got response for us-west-2 c7g.16xlarge 2022-10-09 17:05:40.287657

# %% [markdown]
# ## Plotting Spot price - Individual pools
#
# `spot_prices_dict` does now contain a nested dictionary with regions and instance types as well as the EC2 Spot historic price of each ready to be explored.
#
# Spot price can be display in multiple forms depending which type of aggregation we would like to apply
# Let's apply first no grouping and just iterate over every region and every instance (every column shows a region and every row an instance). Axis are shared to allow for easy comparison.

# %%
plot_spot_prices_grid(cap_price_w.value, spot_prices_dict,instances_w,regions_w)

# %% [markdown]
# ## Plotting Spot price - by Region
# Now let's Iterates over every region and groups all the instance types within the same region.

# %%
plot_spot_aggregated_by_region(cap_price_w.value,spot_prices_dict,instances_w,regions_w, legend=True)

# %% [markdown]
# ## Storing the info into xlsx files
#
# Finally, if you are interested on dumping all the inputs in an excel spreadsheet or similar, the following section will create a excel file for each region with tabs for each instance tab selected. You will be able to download it from jupyter. The files have been created on the same directory you are running the current notebook.

# %%
for region, region_dict in tqdm_notebook(spot_prices_dict.items()):
    excel_writer = pd.ExcelWriter("spot_prices-region-{}.xlsx".format(region), engine='xlsxwriter')
    for instance_type, spot_prices_pd in tqdm_notebook(region_dict.items()):
        spot_prices_pd.to_excel(excel_writer, sheet_name="{}".format(instance_type))
    excel_writer.save()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
